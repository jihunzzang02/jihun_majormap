# %%
import pandas as pd
import numpy as np
from pandas import DataFrame as df
import re
from tqdm import tqdm_notebook
from tqdm.notebook import tqdm
from PIL import Image
import nltk
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
import operator

# %%
data = pd.read_excel('temp_4.xlsx')
data=data.sort_values('출연횟수',ascending = False)
for i in range(len(data)):
    data.loc[i,'주요업무'] = data['주요업무'][i].replace(' 및 ',' ').replace(' 등 ',' ').replace(' and ',' ').replace(' 위 ',' ').replace(' 를 ',' ').replace(' 것 ',' ').replace(' 수 ',' ').replace(' 로 ',' ')
    data.loc[i,'자격요건'] = data['자격요건'][i].replace(' 및 ',' ').replace(' 등 ',' ').replace(' and ',' ').replace(' 위 ',' ').replace(' 를 ',' ').replace(' 것 ',' ').replace(' 수 ',' ').replace(' 로 ',' ')
    data.loc[i,'우대사항'] = data['우대사항'][i].replace(' 및 ',' ').replace(' 등 ',' ').replace(' and ',' ').replace(' 위 ',' ').replace(' 를 ',' ').replace(' 것 ',' ').replace(' 수 ',' ').replace(' 로 ',' ')

# %%
## .inx_num을 설정하는대로 그 인덱스에 해당되는 직무에 관한 정보가 나옵니다.
inx_num = 100
print(data['직무'][inx_num])
x = nltk.Text(data['주요업무'][inx_num].split())
plt.rcParams["figure.figsize"] = (20,10)
plt.rc('font',size = 20)
x.plot(50)
sorted(dict(x.vocab()).items(),key=operator.itemgetter(1), reverse=True)[:50]
# Out:
# 브랜드 마케터
# [('기획', 286),
#  ('마케팅', 266),
#  ('브랜드', 164),
#  ('전략', 139),
#  ('관리', 122),
#  ('운영', 121),
#  ('수립', 109),
#  ('광고', 101),
#  ('채널', 97),
#  ('실행', 84),
#  ('분석', 82),
#  ('제작', 81),
#  ('콘텐츠', 80),
#  ('서비스', 66),
#  ('온라인', 59),
#  ('컨텐츠', 56),
#  ('캠페인', 55),
#  ('오프라인', 54),
#  ('커뮤니케이션', 48),
#  ('sns', 46),
#  ('집행', 42),
#  ('프로모션', 41),
#  ('홍보', 40),
#  ('업무', 38),
#  ('성과', 34),
#  ('이벤트', 33),
#  ('고객', 33),
#  ('페이스북', 33),
#  ('신규', 32),
#  ('제휴', 32),
#  ('통한', 32),
#  ('팀', 30),
#  ('온', 28),
#  ('디지털', 28),
#  ('발굴', 27),
#  ('진행', 27),
#  ('관련', 26),
#  ('marketing', 26),
#  ('데이터', 25),
#  ('브랜딩', 25),
#  ('행사', 24),
#  ('스팅', 24),
#  ('매체', 23),
#  ('pr', 23),
#  ('소셜', 22),
#  ('기반', 22),
#  ('효율', 21),
#  ('프로젝트', 20),
#  ('전반', 20),
#  ('블로그', 20)]
